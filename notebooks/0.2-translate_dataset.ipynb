# %%
from datasets import load_dataset
from tqdm.auto import tqdm
from datasets import Dataset, DatasetDict
from deep_translator import GoogleTranslator


dataset = load_dataset("knkarthick/dialogsum")

# %% [markdown]
# ## write dataset to file iteratively

# %%
file_prefix = "output"
import csv
import os
import pandas as pd

dry_run = False

columns = ['id', 'dialogue', 'summary', 'topic']

# %%
for key in list(dataset.keys()):
    subset = dataset[key]

    file_name = file_prefix + "_" + key + ".csv"

    resuming = os.path.exists(file_name)

    csvfile = open(file_name, "a", newline="")
    csvwriter = csv.writer(csvfile)

    if resuming:
        n_processed = len(pd.read_csv(file_name))
    else:
        n_processed = 0
        csvwriter.writerow(columns)



    for j in tqdm(range(n_processed, len(subset)), desc=key):

        entry = subset[j]
        for column in ['dialogue', 'summary', 'topic']:
            to_translate = entry[column]
            done = False
            n_tries = 0
            max_tries = 10
            while not done:
                try:
                    translated = GoogleTranslator(source='en', target='ru').translate(to_translate)
                    done = True
                except Exception as e:
                    print("got exception:\n", e)
                    n_tries += 1
                    if n_tries > max_tries:
                        break
            if n_tries > max_tries:
                print("Warning: skipped entry", entry["id"], "because it is too big or something else")
                continue
            entry[column] = translated
        csvwriter.writerow([entry[x] for x in columns])

        if dry_run:
            break

    csvfile.close()
# Out:
# train:   0%|          | 0/11241 [00:00<?, ?it/s]
# got exception:
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# got exception:
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# got exception:
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# got exception:
#  HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=ru&sl=en&q=holiday+destination (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f7ad765fe10>: Failed to resolve 'translate.google.com' ([Errno -3] Temporary failure in name resolution)"))
# got exception:
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# got exception:
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# got exception:
# ...

# %%
df = pd.read_csv("output_test.csv")
df
# Out:
#           id                                           dialogue  \
# 0   test_0_1  #Человек1#: Мисс Доусон, мне нужно, чтобы вы п...
# 1   test_0_2  #Человек1#: Мисс Доусон, мне нужно, чтобы вы п...
# 2   test_0_3  #Человек1#: Мисс Доусон, мне нужно, чтобы вы п...
# 3   test_1_1  #Человек1#: Наконец-то ты здесь! Что заняло та...
# 4   test_1_2  #Человек1#: Наконец-то ты здесь! Что заняло та...
# 5   test_1_3  #Человек1#: Наконец-то ты здесь! Что заняло та...
# 6   test_2_1  #Человек1#: Кейт, ты никогда не веришь в то, ч...
# 7   test_2_2  #Человек1#: Кейт, ты никогда не веришь в то, ч...
# 8   test_2_3  #Человек1#: Кейт, ты никогда не веришь в то, ч...
# 9   test_3_1  #Человек1#: С Днем Рождения, это для тебя, Бра...
# 10  test_3_2  #Человек1#: С Днем Рождения, это для тебя, Бра...
# 11  test_3_3  #Человек1#: С Днем Рождения, это для тебя, Бра...
# 12  test_4_1  #Человек1#: Этот олимпийский парк такой большо...
# 13  test_4_2  #Человек1#: Этот олимпийский парк такой большо...
# ...

# %% [markdown]
# в конце желательно еще убедиться, что нет дубликатов строчек, а если есть, удалить их.
